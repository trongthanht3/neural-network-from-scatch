# %%
import pandas as pd
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def pword(text, number):
    texts = text.split('/')
    text = texts[0] + ', ' + 'run_{}'.format(number) + '/' + 'validation'
    return text

# %%
adam = pd.read_csv('log.csv')
adam.run = adam.run.apply(lambda x: pword(x, 1))
adam = adam[:21]
adam.head()
# Out:
#                       run  epoch  epoch_accuracy  epoch_precision  \
# 0  Adam, run_1/validation      1          0.8592         0.871523
# 1  Adam, run_1/validation      2          0.9464         0.946098
# 2  Adam, run_1/validation      3          0.9559         0.956012
# 3  Adam, run_1/validation      4          0.9603         0.960287
# 4  Adam, run_1/validation      5          0.9613         0.961432
#
#    epoch_recall  epoch_f1  epoch_loss
# 0      0.857592  0.853928    0.502985
# 1      0.946082  0.945970    0.395276
# 2      0.955514  0.955566    0.308703
# 3      0.959830  0.959931    0.250298
# 4      0.960808  0.960974    0.238596

# %%
adagrad = pd.read_csv('logAda.csv')
adagrad.run = adagrad.run.apply(lambda x: pword(x, 2))
adagrad = adagrad[:21]
adagrad.head()
# Out:
#                          run  epoch  epoch_accuracy  epoch_precision  \
# 0  Adagrad, run_2/validation      1          0.9011         0.900637
# 1  Adagrad, run_2/validation      2          0.9370         0.936238
# 2  Adagrad, run_2/validation      3          0.9478         0.947422
# 3  Adagrad, run_2/validation      4          0.9538         0.953410
# 4  Adagrad, run_2/validation      5          0.9566         0.956296
#
#    epoch_recall  epoch_f1  epoch_loss
# 0      0.900044  0.899715    0.558042
# 1      0.936339  0.936182    0.389029
# 2      0.947134  0.947168    0.252253
# 3      0.953391  0.953362    0.235593
# 4      0.956273  0.956248    0.243829

# %%
rmsprop = pd.read_csv('logRMS.csv')
rmsprop.run = rmsprop.run.apply(lambda x: pword(x, 3))
rmsprop = rmsprop[:21]
rmsprop.head()
# Out:
#                          run  epoch  epoch_accuracy  epoch_precision  \
# 0  RMSprop, run_3/validation      1          0.7387         0.747090
# 1  RMSprop, run_3/validation      2          0.8988         0.899132
# 2  RMSprop, run_3/validation      3          0.9269         0.926954
# 3  RMSprop, run_3/validation      4          0.9366         0.935982
# 4  RMSprop, run_3/validation      5          0.9396         0.939091
#
#    epoch_recall  epoch_f1  epoch_loss
# 0      0.735283  0.707184    0.968668
# 1      0.897553  0.896648    0.691822
# 2      0.925796  0.925970    0.601470
# 3      0.935585  0.935657    0.498624
# 4      0.938881  0.938872    0.404020

# %%
sgd = pd.read_csv('logSGD.csv')
sgd.run = sgd.run.apply(lambda x: pword(x, 4))
sgd = sgd[:21]
sgd.head()
# Out:
#                      run  epoch  epoch_accuracy  epoch_precision  \
# 0  SGD, run_4/validation      1          0.2569         0.104950
# 1  SGD, run_4/validation      2          0.2904         0.123533
# 2  SGD, run_4/validation      3          0.3330         0.196263
# 3  SGD, run_4/validation      4          0.4809         0.406363
# 4  SGD, run_4/validation      5          0.5686         0.591692
#
#    epoch_recall  epoch_f1  epoch_loss
# 0      0.246023  0.140430    1.844430
# 1      0.280511  0.168205    1.635857
# 2      0.323493  0.221337    1.506812
# 3      0.472561  0.390472    1.335718
# 4      0.562420  0.518908    1.191187

# %%
df_final = adam.append(adagrad).append(rmsprop).append(sgd)
df_final.reset_index(inplace=True, drop=True)
df_final
# Out:
#                        run  epoch  epoch_accuracy  epoch_precision  \
# 0   Adam, run_1/validation      1          0.8592         0.871523
# 1   Adam, run_1/validation      2          0.9464         0.946098
# 2   Adam, run_1/validation      3          0.9559         0.956012
# 3   Adam, run_1/validation      4          0.9603         0.960287
# 4   Adam, run_1/validation      5          0.9613         0.961432
# ..                     ...    ...             ...              ...
# 79   SGD, run_4/validation     17          0.9554         0.955383
# 80   SGD, run_4/validation     18          0.9533         0.953642
# 81   SGD, run_4/validation     19          0.9562         0.956352
# 82   SGD, run_4/validation     20          0.9597         0.959764
# 83   SGD, run_4/validation     21          0.9601         0.960571
#
#     epoch_recall  epoch_f1  epoch_loss
# 0       0.857592  0.853928    0.502985
# 1       0.946082  0.945970    0.395276
# 2       0.955514  0.955566    0.308703
# 3       0.959830  0.959931    0.250298
# 4       0.960808  0.960974    0.238596
# ..           ...       ...         ...
# 79      0.954846  0.955060    0.327496
# 80      0.952792  0.953120    0.337741
# 81      0.955707  0.955972    0.230535
# 82      0.959277  0.959481    0.242243
# 83      0.959660  0.960019    0.224395
#
# [84 rows x 7 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   run              84 non-null     object
#  1   epoch            84 non-null     int64
#  2   epoch_accuracy   84 non-null     float64
#  3   epoch_precision  84 non-null     float64
#  4   epoch_recall     84 non-null     float64
#  5   epoch_f1         84 non-null     float64
#  6   epoch_loss       84 non-null     float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 4.7+ KB

# %%
sns.lineplot(data=df_final, x="epoch", y="epoch_accuracy")
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='epoch_accuracy'>

# %%
# Filter the DataFrame to only validation data, which is what the subsequent
# analyses and visualization will be focused on.
dfw_validation = df_final[df_final.run.str.endswith("/validation")]
dfw_validation
# Out:
#                        run  epoch  epoch_accuracy  epoch_precision  \
# 0   Adam, run_1/validation      1          0.8592         0.871523
# 1   Adam, run_1/validation      2          0.9464         0.946098
# 2   Adam, run_1/validation      3          0.9559         0.956012
# 3   Adam, run_1/validation      4          0.9603         0.960287
# 4   Adam, run_1/validation      5          0.9613         0.961432
# ..                     ...    ...             ...              ...
# 79   SGD, run_4/validation     17          0.9554         0.955383
# 80   SGD, run_4/validation     18          0.9533         0.953642
# 81   SGD, run_4/validation     19          0.9562         0.956352
# 82   SGD, run_4/validation     20          0.9597         0.959764
# 83   SGD, run_4/validation     21          0.9601         0.960571
#
#     epoch_recall  epoch_f1  epoch_loss
# 0       0.857592  0.853928    0.502985
# 1       0.946082  0.945970    0.395276
# 2       0.955514  0.955566    0.308703
# 3       0.959830  0.959931    0.250298
# 4       0.960808  0.960974    0.238596
# ..           ...       ...         ...
# 79      0.954846  0.955060    0.327496
# 80      0.952792  0.953120    0.337741
# 81      0.955707  0.955972    0.230535
# 82      0.959277  0.959481    0.242243
# 83      0.959660  0.960019    0.224395
#
# [84 rows x 7 columns]

# %%
# Filter the DataFrame to only validation data, which is what the subsequent
# analyses and visualization will be focused on.
dfw_validation = df_final[df_final.run.str.endswith("/validation")]
# Get the optimizer value for each row of the validation DataFrame.
optimizer_validation = dfw_validation.run.apply(lambda run: run.split(",")[0])

plt.figure(figsize=(20, 8))
plt.subplot(1, 5, 1)
sns.lineplot(data=dfw_validation, x="epoch", y="epoch_accuracy",
             hue=optimizer_validation, markers=True).set_title("accuracy")
plt.subplot(1, 5, 2)
sns.lineplot(data=dfw_validation, x="epoch", y="epoch_loss",
             hue=optimizer_validation).set_title("loss")
plt.subplot(1, 5, 3)
sns.lineplot(data=dfw_validation, x="epoch", y="epoch_precision",
             hue=optimizer_validation).set_title("precision")
plt.subplot(1, 5, 4)
sns.lineplot(data=dfw_validation, x="epoch", y="epoch_recall",
             hue=optimizer_validation).set_title("recall")
plt.subplot(1, 5, 5)
sns.lineplot(data=dfw_validation, x="epoch", y="epoch_f1",
             hue=optimizer_validation).set_title("f1")
# Out:
# Text(0.5, 1.0, 'f1')

# %%
plt.figure(figsize=(16, 8))
sns.lineplot(data=dfw_validation, x="epoch", y="epoch_accuracy",
             hue=optimizer_validation, marker='o').set_title("accuracy")
# Out:
# Text(0.5, 1.0, 'accuracy')

# %%
plt.figure(figsize=(16, 8))
sns.lineplot(data=dfw_validation, x="epoch", y="epoch_loss",
             hue=optimizer_validation).set_title("loss")
# Out:
# Text(0.5, 1.0, 'loss')

# %%
plt.figure(figsize=(16, 8))
sns.lineplot(data=dfw_validation, x="epoch", y="epoch_precision",
             hue=optimizer_validation).set_title("precision")
# Out:
# Text(0.5, 1.0, 'precision')

# %%
plt.figure(figsize=(16, 8))
sns.lineplot(data=dfw_validation, x="epoch", y="epoch_recall",
             hue=optimizer_validation).set_title("recall")
# Out:
# Text(0.5, 1.0, 'recall')

# %%
plt.figure(figsize=(16, 8))
sns.lineplot(data=dfw_validation, x="epoch", y="epoch_f1",
             hue=optimizer_validation).set_title("f1")
# Out:
# Text(0.5, 1.0, 'f1')
