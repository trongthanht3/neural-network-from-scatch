# %%
import pandas as pd
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def pword(text, number):
    texts = text.split('/')
    text = texts[0] + ', ' + 'run_{}'.format(number) + '/' + 'validation'
    return text

# %%
adam = pd.read_csv('logs/logAdam.csv')
adam.run = adam.run.apply(lambda x: pword(x, 1))
adam = adam[:21]
adam.head()
# Out:
#                       run  epoch  epoch_accuracy  epoch_precision  \
# 0  Adam, run_1/validation      1          0.5937         0.654787
# 1  Adam, run_1/validation      2          0.7705         0.746554
# 2  Adam, run_1/validation      3          0.7983         0.794155
# 3  Adam, run_1/validation      4          0.8146         0.811680
# 4  Adam, run_1/validation      5          0.8227         0.819631
#
#    epoch_recall  epoch_f1  epoch_loss
# 0        0.5937  0.548590    1.031915
# 1        0.7705  0.748335    0.760668
# 2        0.7983  0.787539    0.694770
# 3        0.8146  0.807233    0.617138
# 4        0.8227  0.815830    0.711856

# %%
adagrad = pd.read_csv('logs/logAdagrad.csv')
adagrad.run = adagrad.run.apply(lambda x: pword(x, 2))
adagrad = adagrad[:21]
adagrad.head()
# Out:
#                          run  epoch  epoch_accuracy  epoch_precision  \
# 0  Adagrad, run_2/validation      1          0.7216         0.711805
# 1  Adagrad, run_2/validation      2          0.7796         0.748783
# 2  Adagrad, run_2/validation      3          0.8023         0.792786
# 3  Adagrad, run_2/validation      4          0.8219         0.818401
# 4  Adagrad, run_2/validation      5          0.8252         0.822774
#
#    epoch_recall  epoch_f1  epoch_loss
# 0        0.7216  0.702215    0.965524
# 1        0.7796  0.754512    0.766355
# 2        0.8023  0.787962    0.655430
# 3        0.8219  0.814036    0.666215
# 4        0.8252  0.819400    0.784682

# %%
rmsprop = pd.read_csv('logs/logRMSprop.csv')
rmsprop.run = rmsprop.run.apply(lambda x: pword(x, 3))
rmsprop = rmsprop[:21]
rmsprop.head()
# Out:
#                          run  epoch  epoch_accuracy  epoch_precision  \
# 0  RMSprop, run_3/validation      1          0.6027         0.627361
# 1  RMSprop, run_3/validation      2          0.6664         0.728203
# 2  RMSprop, run_3/validation      3          0.7423         0.743624
# 3  RMSprop, run_3/validation      4          0.7570         0.746541
# 4  RMSprop, run_3/validation      5          0.7729         0.753538
#
#    epoch_recall  epoch_f1  epoch_loss
# 0        0.6027  0.528694    1.053429
# 1        0.6664  0.613806    1.084364
# 2        0.7423  0.718566    0.943794
# 3        0.7570  0.734375    0.993719
# 4        0.7729  0.752487    0.845985

# %%
sgd = pd.read_csv('logs/logSGD.csv')
sgd.run = sgd.run.apply(lambda x: pword(x, 4))
sgd = sgd[:21]
sgd.head()
# Out:
#                      run  epoch  epoch_accuracy  epoch_precision  \
# 0  SGD, run_4/validation      1          0.2029         0.106412
# 1  SGD, run_4/validation      2          0.3426         0.304012
# 2  SGD, run_4/validation      3          0.4746         0.375275
# 3  SGD, run_4/validation      4          0.5676         0.525680
# 4  SGD, run_4/validation      5          0.6594         0.649332
#
#    epoch_recall  epoch_f1  epoch_loss
# 0        0.2029  0.116994    1.977021
# 1        0.3426  0.239797    1.673357
# 2        0.4746  0.372662    1.269037
# 3        0.5676  0.521266    1.141193
# 4        0.6594  0.621909    1.023891

# %%
df_final = adam.append(adagrad).append(rmsprop).append(sgd)
df_final.reset_index(inplace=True, drop=True)
df_final
# Out:
#                        run  epoch  epoch_accuracy  epoch_precision  \
# 0   Adam, run_1/validation      1          0.5937         0.654787
# 1   Adam, run_1/validation      2          0.7705         0.746554
# 2   Adam, run_1/validation      3          0.7983         0.794155
# 3   Adam, run_1/validation      4          0.8146         0.811680
# 4   Adam, run_1/validation      5          0.8227         0.819631
# ..                     ...    ...             ...              ...
# 79   SGD, run_4/validation     17          0.8516         0.850400
# 80   SGD, run_4/validation     18          0.8531         0.851604
# 81   SGD, run_4/validation     19          0.8548         0.854988
# 82   SGD, run_4/validation     20          0.8569         0.856805
# 83   SGD, run_4/validation     21          0.8585         0.858338
#
#     epoch_recall  epoch_f1  epoch_loss
# 0         0.5937  0.548590    1.031915
# 1         0.7705  0.748335    0.760668
# 2         0.7983  0.787539    0.694770
# 3         0.8146  0.807233    0.617138
# 4         0.8227  0.815830    0.711856
# ..           ...       ...         ...
# 79        0.8516  0.850282    0.560053
# 80        0.8531  0.851648    0.589814
# 81        0.8548  0.853568    0.676907
# 82        0.8569  0.856526    0.624860
# 83        0.8585  0.856954    0.524131
#
# [84 rows x 7 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   run              84 non-null     object
#  1   epoch            84 non-null     int64
#  2   epoch_accuracy   84 non-null     float64
#  3   epoch_precision  84 non-null     float64
#  4   epoch_recall     84 non-null     float64
#  5   epoch_f1         84 non-null     float64
#  6   epoch_loss       84 non-null     float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 4.7+ KB

# %%
sns.lineplot(data=df_final, x="epoch", y="epoch_accuracy")
# Out:
# <AxesSubplot:xlabel='epoch', ylabel='epoch_accuracy'>

# %%
# Filter the DataFrame to only validation data, which is what the subsequent
# analyses and visualization will be focused on.
dfw_validation = df_final[df_final.run.str.endswith("/validation")]
dfw_validation
# Out:
#                        run  epoch  epoch_accuracy  epoch_precision  \
# 0   Adam, run_1/validation      1          0.5937         0.654787
# 1   Adam, run_1/validation      2          0.7705         0.746554
# 2   Adam, run_1/validation      3          0.7983         0.794155
# 3   Adam, run_1/validation      4          0.8146         0.811680
# 4   Adam, run_1/validation      5          0.8227         0.819631
# ..                     ...    ...             ...              ...
# 79   SGD, run_4/validation     17          0.8516         0.850400
# 80   SGD, run_4/validation     18          0.8531         0.851604
# 81   SGD, run_4/validation     19          0.8548         0.854988
# 82   SGD, run_4/validation     20          0.8569         0.856805
# 83   SGD, run_4/validation     21          0.8585         0.858338
#
#     epoch_recall  epoch_f1  epoch_loss
# 0         0.5937  0.548590    1.031915
# 1         0.7705  0.748335    0.760668
# 2         0.7983  0.787539    0.694770
# 3         0.8146  0.807233    0.617138
# 4         0.8227  0.815830    0.711856
# ..           ...       ...         ...
# 79        0.8516  0.850282    0.560053
# 80        0.8531  0.851648    0.589814
# 81        0.8548  0.853568    0.676907
# 82        0.8569  0.856526    0.624860
# 83        0.8585  0.856954    0.524131
#
# [84 rows x 7 columns]

# %%
# Filter the DataFrame to only validation data, which is what the subsequent
# analyses and visualization will be focused on.
dfw_validation = df_final[df_final.run.str.endswith("/validation")]
# Get the optimizer value for each row of the validation DataFrame.
optimizer_validation = dfw_validation.run.apply(lambda run: run.split(",")[0])

plt.figure(figsize=(20, 8))
plt.subplot(1, 5, 1)
sns.lineplot(data=dfw_validation, x="epoch", y="epoch_accuracy",
             hue=optimizer_validation, markers=True).set_title("accuracy")
plt.subplot(1, 5, 2)
sns.lineplot(data=dfw_validation, x="epoch", y="epoch_loss",
             hue=optimizer_validation).set_title("loss")
plt.subplot(1, 5, 3)
sns.lineplot(data=dfw_validation, x="epoch", y="epoch_precision",
             hue=optimizer_validation).set_title("precision")
plt.subplot(1, 5, 4)
sns.lineplot(data=dfw_validation, x="epoch", y="epoch_recall",
             hue=optimizer_validation).set_title("recall")
plt.subplot(1, 5, 5)
sns.lineplot(data=dfw_validation, x="epoch", y="epoch_f1",
             hue=optimizer_validation).set_title("f1")
# Out:
# Text(0.5, 1.0, 'f1')

# %%
plt.figure(figsize=(16, 8))
sns.lineplot(data=dfw_validation, x="epoch", y="epoch_accuracy",
             hue=optimizer_validation, marker='o').set_title("accuracy")
# Out:
# Text(0.5, 1.0, 'accuracy')

# %%
plt.figure(figsize=(16, 8))
sns.lineplot(data=dfw_validation, x="epoch", y="epoch_loss",
             hue=optimizer_validation).set_title("loss")
# Out:
# Text(0.5, 1.0, 'loss')

# %%
plt.figure(figsize=(16, 8))
sns.lineplot(data=dfw_validation, x="epoch", y="epoch_precision",
             hue=optimizer_validation).set_title("precision")
# Out:
# Text(0.5, 1.0, 'precision')

# %%
plt.figure(figsize=(16, 8))
sns.lineplot(data=dfw_validation, x="epoch", y="epoch_recall",
             hue=optimizer_validation).set_title("recall")
# Out:
# Text(0.5, 1.0, 'recall')

# %%
plt.figure(figsize=(16, 8))
sns.lineplot(data=dfw_validation, x="epoch", y="epoch_f1",
             hue=optimizer_validation).set_title("f1")
# Out:
# Text(0.5, 1.0, 'f1')
